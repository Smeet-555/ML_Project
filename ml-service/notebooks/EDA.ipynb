# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../dataset/cardio_train.csv', sep=';')

df['age_years'] = df['age'] // 365

print("Dataset Shape:", df.shape)
print("\nFirst 5 rows:")
df.head()
# Out:
# Dataset Shape: (70000, 14)
#
# First 5 rows:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio  age_years
# 0     0       1       0         50
# 1     0       1       1         55
# 2     0       0       1         51
# 3     0       1       1         48
# 4     0       0       0         47

# %%
print("Analytics 1: Basic Statistics")
print(df.describe())
# Out:
# Analytics 1: Basic Statistics
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
print("Analytics 2: Data Types")
print(df.dtypes)
# Out:
# Analytics 2: Data Types
# id               int64
# age              int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# age_years        int64
# dtype: object

# %%
print("Analytics 3: Cardiovascular Disease Value Counts")
print(df['cardio'].value_counts())
# Out:
# Analytics 3: Cardiovascular Disease Value Counts
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %%
print("Analytics 4: Gender Value Counts")
print(df['gender'].value_counts())
# Out:
# Analytics 4: Gender Value Counts
# gender
# 1    45530
# 2    24470
# Name: count, dtype: int64

# %%
print("Analytics 5: Cholesterol Value Counts")
print(df['cholesterol'].value_counts())
# Out:
# Analytics 5: Cholesterol Value Counts
# cholesterol
# 1    52385
# 2     9549
# 3     8066
# Name: count, dtype: int64

# %%
print("Analytics 6: Glucose Value Counts")
print(df['gluc'].value_counts())
# Out:
# Analytics 6: Glucose Value Counts
# gluc
# 1    59479
# 3     5331
# 2     5190
# Name: count, dtype: int64

# %%
print("Analytics 7: Smoking Value Counts")
print(df['smoke'].value_counts())
# Out:
# Analytics 7: Smoking Value Counts
# smoke
# 0    63831
# 1     6169
# Name: count, dtype: int64

# %%
print("Analytics 8: Alcohol Value Counts")
print(df['alco'].value_counts())
# Out:
# Analytics 8: Alcohol Value Counts
# alco
# 0    66236
# 1     3764
# Name: count, dtype: int64

# %%
print("Analytics 9: Active Value Counts")
print(df['active'].value_counts())
# Out:
# Analytics 9: Active Value Counts
# active
# 1    56261
# 0    13739
# Name: count, dtype: int64

# %%
print("Analytics 10: Mean of Numerical Columns")
print(df[['age', 'height', 'weight', 'ap_hi', 'ap_lo']].mean())
# Out:
# Analytics 10: Mean of Numerical Columns
# age       19468.865814
# height      164.359229
# weight       74.205690
# ap_hi       128.817286
# ap_lo        96.630414
# dtype: float64

# %%
print("Analytics 11: Median of Numerical Columns")
print(df[['age', 'height', 'weight', 'ap_hi', 'ap_lo']].median())
# Out:
# Analytics 11: Median of Numerical Columns
# age       19703.0
# height      165.0
# weight       72.0
# ap_hi       120.0
# ap_lo        80.0
# dtype: float64

# %%
print("Analytics 12: Standard Deviation of Numerical Columns")
print(df[['age', 'height', 'weight', 'ap_hi', 'ap_lo']].std())
# Out:
# Analytics 12: Standard Deviation of Numerical Columns
# age       2467.251667
# height       8.210126
# weight      14.395757
# ap_hi      154.011419
# ap_lo      188.472530
# dtype: float64

# %%
print("Analytics 13: Min of Numerical Columns")
print(df[['age', 'height', 'weight', 'ap_hi', 'ap_lo']].min())
# Out:
# Analytics 13: Min of Numerical Columns
# age       10798.0
# height       55.0
# weight       10.0
# ap_hi      -150.0
# ap_lo       -70.0
# dtype: float64

# %%
print("Analytics 14: Max of Numerical Columns")
print(df[['age', 'height', 'weight', 'ap_hi', 'ap_lo']].max())
# Out:
# Analytics 14: Max of Numerical Columns
# age       23713.0
# height      250.0
# weight      200.0
# ap_hi     16020.0
# ap_lo     11000.0
# dtype: float64

# %%
print("Analytics 15: Count of Non-Null Values")
print(df.count())
# Out:
# Analytics 15: Count of Non-Null Values
# id             70000
# age            70000
# gender         70000
# height         70000
# weight         70000
# ap_hi          70000
# ap_lo          70000
# cholesterol    70000
# gluc           70000
# smoke          70000
# alco           70000
# active         70000
# cardio         70000
# age_years      70000
# dtype: int64

# %%
print("Analytics 16: Sum of Numerical Columns")
print(df[['age', 'height', 'weight', 'ap_hi', 'ap_lo']].sum())
# Out:
# Analytics 16: Sum of Numerical Columns
# age       1.362821e+09
# height    1.150515e+07
# weight    5.194398e+06
# ap_hi     9.017210e+06
# ap_lo     6.764129e+06
# dtype: float64
